# %%
import matplotlib.pyplot as plt

# Sample data for the pie chart
labels = ['Category A', 'Category B', 'Category C', 'Category D']
# Sum of sizes should be 100 for a proper pie chart
sizes = [25, 30, 20, 25]
plt.pie(sizes, labels=labels)

# Colors for each category
# colors = ['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon']
# Explode a slice (pull it apart) for emphasis
# explode = (0, 0.1, 0, 0)
# Create a pie chart
# plt.figure(figsize=(8, 8))

#plt.pie(sizes, labels=labels, colors=colors, explode=explode, autopct='%1.1f%%', startangle=90)
plt.axis('equal') # ensures that the pie is drawn as a circle
plt.title('Example Pie Chart')
plt.show()
